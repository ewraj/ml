# %%
# DynamicArray
# ├── _data
# ├── _size
# ├── _capacity
# ├── _resize
# ├── __len__
# ├── __getitem__
# ├── __setitem__
# ├── append
# ├── pop
# └── insert

# %%
class DynamicArray:
    print("Enter the size of array")
    i = int(input("Enter the size of array"))
# Out:
# Enter the size of array
